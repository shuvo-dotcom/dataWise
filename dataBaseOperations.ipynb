# %%
import mysql.connector
import pandas as pd
pd.set_option('display.max_columns', None)

# Connect to the MySQL database
db = mysql.connector.connect(
    host="localhost",
    user="root", 
    password="weatherC",
    database="GlobalWeatherDB"
)

# %%
def displayResults(cursor, results):
    columns = [i[0] for i in cursor.description]
    df = pd.DataFrame(results, columns=columns)
    return df

# %%
cursor = db.cursor()
query = "Describe WeatherData;"
cursor.execute(query)

results = cursor.fetchall()
cursor.close()
print(displayResults(cursor, results))
# Out:
#                            Field           Type Null Key Default Extra
# 0                        country   varchar(100)  YES        None
# 1                  location_name   varchar(100)  YES        None
# 2                       latitude  decimal(10,8)  YES        None
# 3                      longitude  decimal(11,8)  YES        None
# 4                       timezone    varchar(50)  YES        None
# 5             last_updated_epoch         bigint  YES        None
# 6                   last_updated       datetime  YES        None
# 7            temperature_celsius   decimal(5,2)  YES        None
# 8         temperature_fahrenheit   decimal(5,2)  YES        None
# 9                 condition_text   varchar(100)  YES        None
# 10                wind_speed_mph   decimal(7,2)  YES        None
# 11                wind_speed_kph   decimal(7,2)  YES        None
# 12                   wind_degree            int  YES        None
# 13                wind_direction     varchar(3)  YES        None
# 14                   pressure_mb   decimal(7,2)  YES        None
# 15                   pressure_in   decimal(7,2)  YES        None
# 16              precipitation_mm   decimal(5,2)  YES        None
# 17              precipitation_in   decimal(5,2)  YES        None
# 18                      humidity            int  YES        None
# 19                cloud_coverage            int  YES        None
# 20            feels_like_celsius   decimal(5,2)  YES        None
# 21         feels_like_fahrenheit   decimal(5,2)  YES        None
# 22                 visibility_km   decimal(5,2)  YES        None
# 23              visibility_miles   decimal(5,2)  YES        None
# 24                      uv_index   decimal(5,2)  YES        None
# 25                gust_speed_mph   decimal(7,2)  YES        None
# 26                gust_speed_kph   decimal(7,2)  YES        None
# 27   air_quality_carbon_monoxide   decimal(7,2)  YES        None
# 28             air_quality_ozone   decimal(5,2)  YES        None
# 29  air_quality_nitrogen_dioxide   decimal(5,2)  YES        None
# 30    air_quality_sulfur_dioxide   decimal(7,2)  YES        None
# 31             air_quality_pm2_5   decimal(7,2)  YES        None
# 32              air_quality_pm10   decimal(7,2)  YES        None
# 33      air_quality_us_epa_index            int  YES        None
# 34    air_quality_gb_defra_index            int  YES        None
# 35                       sunrise    varchar(20)  YES        None
# 36                        sunset    varchar(20)  YES        None
# 37                      moonrise    varchar(20)  YES        None
# 38                       moonset    varchar(20)  YES        None
# 39                    moon_phase    varchar(50)  YES        None
# 40             moon_illumination   decimal(5,2)  YES        None

# %% [markdown]
# Retrieve the top 5 locations with the highest temperatures or
# lowest precipitation.

# %%
cursor = db.cursor()
query = "SELECT location_name, MAX(temperature_celsius) AS max_temperature FROM WeatherData GROUP BY location_name ORDER BY max_temperature DESC LIMIT 5;"
cursor.execute(query)

results = cursor.fetchall()
cursor.close()
print(displayResults(cursor, results))
# Out:
#   location_name max_temperature
# 0   Kuwait City           49.20
# 1       Baghdad           49.10
# 2      Djibouti           47.10
# 3        Riyadh           46.30
# 4          Doha           46.20

# %% [markdown]
# Retrieve all records for a specific date or condition (e.g., temperature >= 35°C, precipitation >= 100 mm).

# %%
cursor = db.cursor()
query = "SELECT * FROM WeatherData WHERE temperature_celsius > 35 OR precipitation_mm >= 100;"
cursor.execute(query)
results = cursor.fetchall()
cursor.close()
print(displayResults(cursor, results))
# Out:
#            country location_name     latitude     longitude         timezone  \
# 0          Bahrain        Manama  26.24000000   50.58000000     Asia/Bahrain
# 1       Bangladesh         Dhaka  23.72000000   90.41000000       Asia/Dhaka
# 2         Cambodia    Phnom Penh  11.55000000  104.92000000  Asia/Phnom_Penh
# 3             Chad     N'djamena  12.11000000   15.05000000    Africa/Douala
# 4            India     New Delhi  28.60000000   77.20000000     Asia/Kolkata
# ...            ...           ...          ...           ...              ...
# 2379         Sudan      Khartoum  15.58810000   32.53420000  Africa/Khartoum
# 2380          Iraq       Baghdad  33.33860000   44.39390000     Asia/Baghdad
# 2381         Qatar          Doha  25.28670000   51.53330000       Asia/Qatar
# 2382  Saudi Arabia        Riyadh  24.64080000   46.77280000      Asia/Riyadh
# 2383         Sudan      Khartoum  15.58810000   32.53420000  Africa/Khartoum
#
#       last_updated_epoch        last_updated temperature_celsius  \
# 0             1715849100 2024-05-16 11:45:00               36.00
# 1             1715849100 2024-05-16 14:45:00               38.40
# 2             1715849100 2024-05-16 15:45:00               38.00
# 3             1715849100 2024-05-16 09:45:00               37.20
# 4             1715849100 2024-05-16 14:15:00               42.00
# ...                  ...                 ...                 ...
# 2379          1728811800 2024-10-13 11:30:00               35.80
# 2380          1728898200 2024-10-14 12:30:00               36.20
# 2381          1728898200 2024-10-14 12:30:00               36.00
# 2382          1728898200 2024-10-14 12:30:00               36.10
# 2383          1728898200 2024-10-14 11:30:00               36.30
#
#      temperature_fahrenheit condition_text wind_speed_mph wind_speed_kph  \
# 0                     96.80          Sunny          13.60          22.00
# 1                    101.20  Partly Cloudy           4.30           6.80
# 2                    100.40  Partly cloudy           6.90          11.20
# 3                     98.90          Sunny           8.90          14.40
# 4                    107.60           Mist           6.90          11.20
# ...                     ...            ...            ...            ...
# 2379                  96.50  Partly Cloudy           5.40           8.60
# 2380                  97.20           Mist           2.90           4.70
# 2381                  96.80          Sunny           8.30          13.30
# 2382                  97.00          Sunny          12.80          20.50
# 2383                  97.40          Sunny           5.60           9.00
#
#       wind_degree wind_direction pressure_mb pressure_in precipitation_mm  \
# 0             140             SE     1007.00       29.74             0.00
# 1             222             SW     1006.00       29.71             0.00
# 2             160            SSE     1005.00       29.68             0.00
# 3             150            SSE     1010.00       29.82             0.00
# 4             330            NNW     1008.00       29.77             0.00
# ...           ...            ...         ...         ...              ...
# 2379          251            WSW     1011.00       29.85             0.00
# 2380          289            WNW     1009.00       29.79             0.00
# 2381           68            ENE     1009.00       29.80             0.00
# 2382          146            SSE     1013.00       29.91             0.00
# 2383          310             NW     1010.00       29.83             0.00
#
#      precipitation_in  humidity  cloud_coverage feels_like_celsius  \
# 0                0.00        33               0              45.40
# 1                0.00        31              30              41.30
# 2                0.00        45              50              42.40
# 3                0.00        27               2              37.90
# 4                0.00        13               0              43.00
# ...               ...       ...             ...                ...
# 2379             0.00        28              27              36.00
# 2380             0.00        19               0              34.70
# 2381             0.00        29               0              37.50
# 2382             0.00        12               0              34.50
# 2383             0.00        24               5              35.70
#
#      feels_like_fahrenheit visibility_km visibility_miles uv_index  \
# 0                   113.60         10.00             6.00     8.00
# 1                   106.40         10.00             6.00     9.00
# 2                   108.30         10.00             6.00     9.00
# 3                   100.20         10.00             6.00     9.00
# 4                   109.30          4.00             2.00    10.00
# ...                    ...           ...              ...      ...
# 2379                 96.90         10.00             6.00     8.70
# 2380                 94.40          8.00             4.00     5.40
# 2381                 99.40         10.00             6.00     7.20
# 2382                 94.20         10.00             6.00     8.20
# 2383                 96.20         10.00             6.00     9.10
#
#      gust_speed_mph gust_speed_kph air_quality_carbon_monoxide  \
# 0             18.10          29.20                      397.20
# 1              4.90           7.90                      520.70
# 2              9.80          15.70                     1295.10
# 3             10.30          16.60                      480.70
# 4             11.40          18.40                      307.10
# ...             ...            ...                         ...
# 2379           6.20           9.90                      401.45
# 2380           3.40           5.50                     5181.85
# 2381           9.50          15.30                      414.40
# 2382          14.70          23.60                      521.70
# 2383           6.40          10.40                      468.05
#
#      air_quality_ozone air_quality_nitrogen_dioxide  \
# 0               100.10                        18.50
# 1               188.80                         8.70
# 2                46.50                        14.90
# 3                37.20                         1.00
# 4               144.50                         3.00
# ...                ...                          ...
# 2379             82.00                         6.85
# 2380             34.00                       257.89
# 2381            119.00                        49.77
# 2382             65.00                        70.86
# 2383             88.00                         7.77
#
#      air_quality_sulfur_dioxide air_quality_pm2_5 air_quality_pm10  \
# 0                          9.70             39.00           114.30
# 1                          4.70             49.70            57.00
# 2                         10.00             17.10            23.00
# 3                          0.90             13.60            38.80
# 4                          6.10             25.40            64.00
# ...                         ...               ...              ...
# 2379                       3.52             38.85           118.40
# 2380                     147.08            101.38           155.77
# 2381                      17.95             53.47           132.65
# 2382                     174.64             57.35           205.54
# 2383                       4.26             63.27           246.42
#
#       air_quality_us_epa_index  air_quality_gb_defra_index   sunrise  \
# 0                            2                           4  04:50 AM
# 1                            3                           6  05:16 AM
# 2                            2                           2  05:37 AM
# 3                            1                           2  05:36 AM
# 4                            2                           3  05:30 AM
# ...                        ...                         ...       ...
# 2379                         2                           4  05:42 AM
# 2380                         4                          10  06:06 AM
# 2381                         3                           6  05:32 AM
# 2382                         3                           7  05:51 AM
# 2383                         3                           8  05:42 AM
#
#         sunset  moonrise   moonset      moon_phase moon_illumination
# 0     06:18 PM  12:10 PM  12:45 AM  Waxing Gibbous             55.00
# 1     06:34 PM  12:28 PM  12:58 AM  Waxing Gibbous             55.00
# 2     06:17 PM  12:41 PM  12:43 AM  Waxing Gibbous             55.00
# 3     06:17 PM  12:51 PM  12:53 AM  Waxing Gibbous             55.00
# 4     07:06 PM  12:47 PM  01:30 AM  Waxing Gibbous             55.00
# ...        ...       ...       ...             ...               ...
# 2379  05:31 PM  02:35 PM  01:25 AM  Waxing Gibbous             73.00
# 2380  05:30 PM  03:46 PM  02:13 AM  Waxing Gibbous             83.00
# 2381  05:07 PM  03:09 PM  01:55 AM  Waxing Gibbous             83.00
# 2382  05:27 PM  03:28 PM  02:15 AM  Waxing Gibbous             83.00
# 2383  05:30 PM  03:19 PM  02:25 AM  Waxing Gibbous             83.00
#
# [2384 rows x 41 columns]

# %% [markdown]
# Perform a group by operation (e.g., average temperature by country, total precipitation by region).

# %%
cursor = db.cursor()
query = '''
SELECT location_name, AVG(temperature_celsius) AS average_temperature
FROM WeatherData
GROUP BY location_name;
'''
cursor.execute(query)
results = cursor.fetchall()
cursor.close()
print(displayResults(cursor, results))
# Out:
#             location_name average_temperature
# 0                   Kabul           27.441060
# 1                  Tirana           30.376159
# 2                 Algiers           28.769333
# 3        Andorra La Vella           18.373510
# 4                  Luanda           25.861589
# ..                    ...                 ...
# 243    City Of San Marino           31.300000
# 244             Ar Riyadh           45.000000
# 245  Krasnyy Turkmenistan           37.800000
# 246              -Kingdom           29.700000
# 247                 Airai           27.580328
#
# [248 rows x 2 columns]

# %%
cursor = db.cursor()
query = '''
SELECT location_name, AVG(precipitation_mm) AS average_precip_mm
FROM WeatherData
GROUP BY location_name;
'''
cursor.execute(query)
results = cursor.fetchall()
cursor.close()
print(displayResults(cursor, results))
# Out:
#             location_name average_precip_mm
# 0                   Kabul          0.057947
# 1                  Tirana          0.174636
# 2                 Algiers          0.004267
# 3        Andorra La Vella          0.188609
# 4                  Luanda          0.000199
# ..                    ...               ...
# 243    City Of San Marino          0.000000
# 244             Ar Riyadh          0.000000
# 245  Krasnyy Turkmenistan          0.000000
# 246              -Kingdom          0.000000
# 247                 Airai          0.516393
#
# [248 rows x 2 columns]

# %%
from pymongo import MongoClient

# Connect to the MongoDB server
client = MongoClient('mongodb://localhost:27017/')  # Update with your MongoDB URI if necessary

# Access the database and collection
db = client.WeatherData
collection = db.weather_data

# 1. Retrieve all records for a specific continent or month
records_condition = list(collection.find(
    {
    '$or': [
        { 'country': 'India' },
    ]
}
))

df_condition = pd.DataFrame(records_condition)
print("Records matching specific condition:")
print(df_condition)

# 2. Retrieve the top 3 hottest locations
top_hottest = list(collection.find().sort('temperature_celsius', -1).limit(3))
df_top_hottest = pd.DataFrame(top_hottest)
print("\nTop 3 hottest locations:")
print(df_top_hottest)

# 3. Retrieve the top 3 days with the highest precipitation
top_precipitation = list(collection.find().sort('precipitation_mm', -1).limit(3))
df_top_precipitation = pd.DataFrame(top_precipitation)
print("\nTop 3 days with highest precipitation:")
print(df_top_precipitation)
# Out:
# Records matching specific condition:
#                           _id country location_name  latitude  longitude  \
# 0    671185362a4b3e29b2d4dad6   India     New Delhi      28.6       77.2
# 1    671185362a4b3e29b2d4dba0   India     New Delhi      28.6       77.2
# 2    671185362a4b3e29b2d4dc89   India     New Delhi      28.6       77.2
# 3    671185362a4b3e29b2d4dd28   India     New Delhi      28.6       77.2
# 4    671185362a4b3e29b2d4dddf   India     New Delhi      28.6       77.2
# ..                        ...     ...           ...       ...        ...
# 144  671185372a4b3e29b2d5499a   India     New Delhi      28.6       77.2
# 145  671185372a4b3e29b2d54a4e   India     New Delhi      28.6       77.2
# 146  671185372a4b3e29b2d54b12   India     New Delhi      28.6       77.2
# 147  671185372a4b3e29b2d54bdc   India     New Delhi      28.6       77.2
# 148  671185372a4b3e29b2d54c9e   India     New Delhi      28.6       77.2
#
#          timezone  last_updated_epoch      last_updated  temperature_celsius  \
# 0    Asia/Kolkata          1715849100  2024-05-16 14:15                 42.0
# 1    Asia/Kolkata          1715868000  2024-05-16 19:30                 38.0
# 2    Asia/Kolkata          1715961600  2024-05-17 21:30                 36.0
# 3    Asia/Kolkata          1716042600  2024-05-18 20:00                 41.0
# 4    Asia/Kolkata          1716128100  2024-05-19 19:45                 41.0
# ..            ...                 ...               ...                  ...
# 144  Asia/Kolkata          1728553500  2024-10-10 15:15                 35.4
# 145  Asia/Kolkata          1728639900  2024-10-11 15:15                 35.2
# 146  Asia/Kolkata          1728726300  2024-10-12 15:15                 33.3
# 147  Asia/Kolkata          1728811800  2024-10-13 15:00                 34.4
# 148  Asia/Kolkata          1728898200  2024-10-14 15:00                 33.3
#
#      temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 0                     107.6           Mist       6.9      11.2          330
# 1                     100.4           Mist       6.9      11.2           50
# 2                      96.8           Mist       2.2       3.6           10
# 3                     105.8           Mist       6.9      11.2          300
# 4                     105.8           Mist       6.9      11.2          290
# ..                      ...            ...       ...       ...          ...
# 144                    95.7          Sunny       8.7      14.0          320
# 145                    95.4          Sunny       8.5      13.7          330
# 146                    91.9           Mist       5.4       8.6          335
# 147                    93.9           Mist       2.2       3.6          184
# 148                    91.9           Mist       8.5      13.7          344
#
#     wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# 0              NNW       1008.0        29.77        0.0        0.0        13
# 1               NE       1005.0        29.68        0.0        0.0        23
# 2                N       1003.0        29.62        0.0        0.0        21
# 3              WNW       1000.0        29.53        0.0        0.0        15
# 4              WNW        999.0        29.50        0.0        0.0        14
# ..             ...          ...          ...        ...        ...       ...
# 144             NW       1007.0        29.74        0.0        0.0        18
# 145            NNW       1007.0        29.73        0.0        0.0        16
# 146            NNW       1011.0        29.85        0.0        0.0        34
# 147              S       1011.0        29.85        0.0        0.0        23
# 148            NNW       1012.0        29.88        0.0        0.0        28
#
#      cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 0        0                43.0                  109.3            4.0
# 1        0                37.1                   98.7            3.5
# 2        0                34.4                   94.0            3.5
# 3        0                41.4                  106.6            4.0
# 4        0                41.4                  106.6            4.0
# ..     ...                 ...                    ...            ...
# 144     10                33.7                   92.6           10.0
# 145      0                33.5                   92.2           10.0
# 146     25                31.2                   88.1            5.0
# 147     50                32.5                   90.4            5.0
# 148      0                31.2                   88.1            4.5
#
#      visibility_miles  uv_index  gust_mph  gust_kph  \
# 0                 2.0      10.0      11.4      18.4
# 1                 2.0       1.0       8.3      13.4
# 2                 2.0       1.0       5.4       8.7
# 3                 2.0       1.0      18.0      29.0
# 4                 2.0       1.0      13.1      21.1
# ..                ...       ...       ...       ...
# 144               6.0       2.0      10.0      16.2
# 145               6.0       2.2       9.8      15.7
# 146               3.0       2.0       6.2       9.9
# 147               3.0       1.9       6.7      10.8
# 148               2.0       1.9       9.8      15.7
#
#      air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0                         307.10              144.5
# 1                         741.00              120.2
# 2                         907.90               88.7
# 3                         454.00              128.8
# 4                         527.40              113.0
# ..                           ...                ...
# 144                       997.15              144.0
# 145                      1084.10              146.0
# 146                      1296.85              165.0
# 147                      2173.75              221.0
# 148                       939.80              118.0
#
#      air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 0                           3.000                        6.100
# 1                          22.600                       22.900
# 2                          24.700                       19.300
# 3                           8.400                       10.400
# 4                          12.700                       11.700
# ..                            ...                          ...
# 144                        31.080                       40.700
# 145                        34.780                       40.515
# 146                        45.880                       49.395
# 147                        84.360                       87.505
# 148                        31.265                       42.180
#
#     air_quality_PM2  air_quality_PM10  air_quality_us-epa-index  \
# 0       {'5': 25.4}            64.000                         2
# 1       {'5': 44.0}            80.800                         3
# 2       {'5': 49.7}            83.700                         3
# 3       {'5': 32.5}            58.700                         2
# 4       {'5': 31.7}            55.000                         2
# ..              ...               ...                       ...
# 144   {'5': 77.885}           148.185                         4
# 145    {'5': 77.33}           128.020                         4
# 146   {'5': 73.075}           159.285                         4
# 147   {'5': 134.31}           220.520                         4
# 148   {'5': 78.625}           132.275                         4
#
#      air_quality_gb-defra-index   sunrise    sunset  moonrise     moonset  \
# 0                             3  05:30 AM  07:06 PM  12:47 PM    01:30 AM
# 1                             5  05:30 AM  07:06 PM  12:47 PM    01:30 AM
# 2                             6  05:30 AM  07:06 PM  01:40 PM    01:58 AM
# 3                             3  05:29 AM  07:07 PM  02:32 PM    02:24 AM
# 4                             3  05:28 AM  07:08 PM  03:24 PM    02:51 AM
# ..                          ...       ...       ...       ...         ...
# 144                          10  06:19 AM  05:57 PM  01:05 PM    11:13 PM
# 145                          10  06:20 AM  05:56 PM  01:56 PM  No moonset
# 146                          10  06:20 AM  05:55 PM  02:40 PM    12:18 AM
# 147                          10  06:21 AM  05:54 PM  03:20 PM    01:25 AM
# 148                          10  06:21 AM  05:53 PM  03:57 PM    02:32 AM
#
#          moon_phase  moon_illumination
# 0    Waxing Gibbous                 55
# 1    Waxing Gibbous                 55
# 2    Waxing Gibbous                 64
# 3    Waxing Gibbous                 73
# 4    Waxing Gibbous                 81
# ..              ...                ...
# 144   First Quarter                 42
# 145  Waxing Gibbous                 52
# 146  Waxing Gibbous                 63
# 147  Waxing Gibbous                 73
# 148  Waxing Gibbous                 83
#
# [149 rows x 42 columns]
#
# Top 3 hottest locations:
#                         _id country location_name  latitude  longitude  \
# 0  671185362a4b3e29b2d4f580  Kuwait   Kuwait City     29.37      47.96
# 1  671185372a4b3e29b2d50619    Iraq       Baghdad     33.34      44.39
# 2  671185362a4b3e29b2d4f7ae    Iraq       Baghdad     33.34      44.39
#
#        timezone  last_updated_epoch      last_updated  temperature_celsius  \
# 0   Asia/Kuwait          1718804700  2024-06-19 16:45                 49.2
# 1  Asia/Baghdad          1720701900  2024-07-11 15:45                 49.1
# 2  Asia/Baghdad          1719063900  2024-06-22 16:45                 49.1
#
#    temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 0                   120.6          Sunny      13.6      22.0          330
# 1                   120.3          Sunny      12.8      20.5          307
# 2                   120.4  Partly cloudy       6.9      11.2          200
#
#   wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# 0            NNW        996.0        29.42        0.0        0.0         4
# 1             NW        999.0        29.50        0.0        0.0         6
# 2            SSW        994.0        29.36        0.0        0.0         8
#
#    cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 0      0                51.2                  124.2           14.0
# 1      0                51.1                  123.9           10.0
# 2     25                51.1                  124.0           10.0
#
#    visibility_miles  uv_index  gust_mph  gust_kph  \
# 0               8.0      10.0      24.3      39.2
# 1               6.0      11.0      14.7      23.6
# 2               6.0      11.0      11.1      17.8
#
#    air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0                        208.6              135.9
# 1                        210.3              157.4
# 2                        208.6              148.8
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide air_quality_PM2  \
# 0                           3.7                          0.8     {'5': 33.6}
# 1                           4.2                          3.6     {'5': 12.3}
# 2                           3.8                          2.3     {'5': 16.1}
#
#    air_quality_PM10  air_quality_us-epa-index  air_quality_gb-defra-index  \
# 0             187.0                         2                           3
# 1              39.5                         1                           2
# 2              47.9                         2                           2
#
#     sunrise    sunset  moonrise   moonset       moon_phase  moon_illumination
# 0  04:49 AM  06:50 PM  04:33 PM  02:17 AM   Waxing Gibbous                 90
# 1  05:02 AM  07:14 PM  09:58 AM  10:37 PM  Waxing Crescent                 23
# 2  04:54 AM  07:16 PM  08:06 PM  04:42 AM        Full Moon                100
#
# Top 3 days with highest precipitation:
#                         _id      country location_name  latitude  longitude  \
# 0  671185362a4b3e29b2d4da90  Afghanistan         Kabul     34.52      69.18
# 1  671185362a4b3e29b2d4da91      Albania        Tirana     41.33      19.82
# 2  671185362a4b3e29b2d4da92      Algeria       Algiers     36.76       3.05
#
#          timezone  last_updated_epoch      last_updated  temperature_celsius  \
# 0      Asia/Kabul          1715849100  2024-05-16 13:15                 26.6
# 1   Europe/Tirane          1715849100  2024-05-16 10:45                 19.0
# 2  Africa/Algiers          1715849100  2024-05-16 09:45                 23.0
#
#    temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 0                    79.8  Partly Cloudy       8.3      13.3          338
# 1                    66.2  Partly cloudy       6.9      11.2          320
# 2                    73.4          Sunny       9.4      15.1          280
#
#   wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# 0            NNW       1012.0        29.89        0.0        0.0        24
# 1             NW       1012.0        29.88        0.1        0.0        94
# 2              W       1011.0        29.85        0.0        0.0        29
#
#    cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 0     30                25.3                   77.5           10.0
# 1     75                19.0                   66.2           10.0
# 2      0                24.6                   76.4           10.0
#
#    visibility_miles  uv_index  gust_mph  gust_kph  \
# 0               6.0       7.0       9.5      15.3
# 1               6.0       5.0      11.4      18.4
# 2               6.0       5.0      13.9      22.3
#
#    air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0                        277.0              103.0
# 1                        193.6               97.3
# 2                        540.7               12.2
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide air_quality_PM2  \
# 0                           1.1                          0.2      {'5': 8.4}
# 1                           0.9                          0.1      {'5': 1.1}
# 2                          65.1                         13.4     {'5': 10.4}
#
#    air_quality_PM10  air_quality_us-epa-index  air_quality_gb-defra-index  \
# 0              26.6                         1                           1
# 1               2.0                         1                           1
# 2              18.4                         1                           1
#
#     sunrise    sunset  moonrise   moonset      moon_phase  moon_illumination
# 0  04:50 AM  06:50 PM  12:12 PM  01:11 AM  Waxing Gibbous                 55
# 1  05:21 AM  07:54 PM  12:58 PM  02:14 AM  Waxing Gibbous                 55
# 2  05:40 AM  07:50 PM  01:15 PM  02:14 AM  Waxing Gibbous                 55
